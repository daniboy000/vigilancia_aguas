# %% [markdown]
# # Relatório Vigilância das Águas

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# #### Funções Auxiliares

# %%
def convert_string_to_datetime(date):
    return pd.to_datetime(date, format='%d/%m/%Y')


def read_excel_file(file_name):
    return pd.read_excel(file_name,
                         engine='openpyxl',
                         decimal=',',
                         converters={
                                       'Data da coleta': convert_string_to_datetime,
                                       'Data do laudo': convert_string_to_datetime,
                                       'Data de registro SISAGUA': convert_string_to_datetime,                                            
                                    })


def convert_string_to_nan(data_frame, word):
    return data_frame.replace(word, np.nan)


def drop_na_from_column(data_frame, column_name):
    return data_frame.dropna(subset=[column_name,])


def get_month_from_row(data_frame):
    return pd.to_datetime(data_frame['Data da coleta']).dt.month


def get_municipios_from_dataframe(data_frame):
    return data_frame['Município'].unique()


def get_municipios_invalidos(municipios, data_frame):
    return municipios[data_frame.groupby(['Município'])['mes_analise'].nunique() < 4]


def get_municipios_validos(municipios, data_frame):
    return municipios[data_frame.groupby(['Município'])['mes_analise'].nunique() >= 4]


def remove_municipios_from_dataframe(municipios_invalidos, data_frame):
    return data_frame[~data_frame['Município'].isin(municipios_invalidos)]


def group_by_fluoretacao_and_municipio(data_frame):
    return data_frame.groupby(['Município'])['Fluoreto(mg/L)'].value_counts()


def get_soma_fluoretacao(data_frame):
    return data_frame.groupby(['Município']).sum()


def get_municipios_with_valid_samples(data_frame, municipios_validos, municipios_soma):
    municipios_analises_validas = []
    for mun in municipios_validos:
        if data_frame[mun].get(0.0, 0) != municipios_soma[mun]:
            municipios_analises_validas.append(mun)
    return municipios_analises_validas


def get_data_frame_with_valid_samples(data_frame, municipios_analises_validas):
    return data_frame[data_frame['Município'].isin(municipios_analises_validas)]

# %% [markdown]
# #### Leitura dos arquivos excel

# %%
file_2020 = "./files/Relatório Vigilância das águas 01.01.2020 A 31.12.2020- SAA.xlsx"
#file_2021 = "./files/Relatório Vigilância das águas 01.01.2020 A 31.12.2020- SAA.xlsx"
#file_2022 = "./files/Relatório Vigilância das águas 01.01.2020 A 31.12.2020- SAA.xlsx"

output_2020 = "./files/limpo_2020.xlsx"

# %%
df_2020_raw = read_excel_file(file_name=file_2020)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.virtualenvs/renata/lib/python3.11/site-packages/pandas/compat/_optional.py:132, in import_optional_dependency(name, extra, errors, min_version)
#     131 try:
# --> 132     module = importlib.import_module(name)
#     133 except ImportError:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_2020_raw = read_excel_file(file_name=file_2020)
#
# Cell In[5], line 6, in read_excel_file(file_name)
#       5 def read_excel_file(file_name):
# ----> 6     return pd.read_excel(file_name,
#       7                          engine='openpyxl',
#       8                          decimal=',',
#       9                          converters={
#      10                                        'Data da coleta': convert_string_to_datetime,
#      11                                        'Data do laudo': convert_string_to_datetime,
#      12                                        'Data de registro SISAGUA': convert_string_to_datetime,
#      13                                     })
#
# File ~/.virtualenvs/renata/lib/python3.11/site-packages/pandas/io/excel/_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File ~/.virtualenvs/renata/lib/python3.11/site-packages/pandas/io/excel/_base.py:1580, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1577 self.engine = engine
#    1578 self.storage_options = storage_options
# -> 1580 self._reader = self._engines[engine](
#    1581     self._io,
#    1582     storage_options=storage_options,
#    1583     engine_kwargs=engine_kwargs,
#    1584 )
#
# File ~/.virtualenvs/renata/lib/python3.11/site-packages/pandas/io/excel/_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)
#     539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)
#     550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File ~/.virtualenvs/renata/lib/python3.11/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     133 except ImportError:
#     134     if errors == "raise":
# --> 135         raise ImportError(msg)
#     136     return None
#     138 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
df_2020_raw.head()
# Out:
#       Município  Código IBGE  Motivo Forma              Nome         Código  \
# 0  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 1  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 2  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 3  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 4  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
#
#   N° da amostra Data da coleta Data do laudo Data de registro SISAGUA  ...  \
# 0  200907000002     2020-01-09    2020-01-10               2020-01-13  ...
# 1  200907000001     2020-01-09    2020-01-10               2020-01-13  ...
# 2  200907000003     2020-01-09    2020-01-10               2020-01-13  ...
# 3  200907000004     2020-01-09    2020-01-10               2020-01-13  ...
# 4  200907000006     2020-01-09    2020-01-10               2020-01-13  ...
#
#    E. coli Cloro Residual Livre(mg/L) Cloro Residual Combinado (mg/L)  \
# 0  Ausente                       1.33                             NaN
# 1  Ausente                       2.15                             NaN
# 2  Ausente                       0.94                             NaN
# 3  Ausente                       1.27                             NaN
# 4  Ausente                       2.26                             NaN
#
#   Dióxido de Cloro (mg/L) Turbidez(uT) Fluoreto(mg/L) Fluoretação  \
# 0                     NaN         0.90            0.8         Sim
# 1                     NaN         0.81            0.8         Sim
# 2                     NaN         1.10  Não realizada         Sim
# 3                     NaN         0.69            0.8         Sim
# 4                     NaN         0.84            0.8         Sim
#
#    Bactérias Heterotróficas(UFC/mL)  Cor Aparente (uH)    pH
# 0                     Não realizada      Não realizada  6.50
# 1                     Não realizada      Não realizada  6.50
# 2                     Não realizada      Não realizada  6.50
# 3                     Não realizada      Não realizada  6.50
# 4                     Não realizada      Não realizada  6.50
#
# [5 rows x 32 columns]

# %%
df_2020_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38782 entries, 0 to 38781
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Município                         38782 non-null  object
#  1   Código IBGE                       38782 non-null  int64
#  2   Motivo                            38782 non-null  object
#  3   Forma                             38782 non-null  object
#  4   Nome                              38782 non-null  object
#  5   Código                            38782 non-null  object
#  6   N° da amostra                     38782 non-null  object
#  7   Data da coleta                    38782 non-null  datetime64[ns]
#  8   Data do laudo                     38782 non-null  datetime64[ns]
#  9   Data de registro SISAGUA          38782 non-null  datetime64[ns]
#  10  Procedência da coleta             38782 non-null  object
#  11  Ponto de coleta                   38782 non-null  object
#  12  Categoria da Área                 38782 non-null  object
#  13  Zona                              38782 non-null  object
#  14  Área/Nome                         38782 non-null  object
#  15  Local                             9756 non-null   object
#  16  Descrição do local                38476 non-null  object
#  17  Latitude                          622 non-null    float64
#  18  Longitude                         622 non-null    float64
#  19  Hora da coleta                    38782 non-null  object
#  20  Chuva nas últimas 48h             38782 non-null  object
#  21  Coliformes totais                 38782 non-null  object
#  22  E. coli                           38782 non-null  object
#  23  Cloro Residual Livre(mg/L)        36019 non-null  object
#  24  Cloro Residual Combinado (mg/L)   182 non-null    object
#  25  Dióxido de Cloro (mg/L)           140 non-null    object
#  26  Turbidez(uT)                      38782 non-null  object
#  27  Fluoreto(mg/L)                    38782 non-null  object
#  28  Fluoretação                       38782 non-null  object
#  29  Bactérias Heterotróficas(UFC/mL)  38782 non-null  object
#  30  Cor Aparente (uH)                 38782 non-null  object
#  31  pH                                38782 non-null  object
# dtypes: datetime64[ns](3), float64(2), int64(1), object(26)
# memory usage: 9.5+ MB

# %% [markdown]
# ## Limpeza dos dados

# %% [markdown]
# #### Conversão de **"Não realizada"** para **np.nan**

# %%
df_2020_no_nan = convert_string_to_nan(df_2020_raw, 'Não realizada')

# %%
df_2020_no_nan.head()
# Out:
#       Município  Código IBGE  Motivo Forma              Nome         Código  \
# 0  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 1  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 2  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 3  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 4  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
#
#   N° da amostra Data da coleta Data do laudo Data de registro SISAGUA  ...  \
# 0  200907000002     2020-01-09    2020-01-10               2020-01-13  ...
# 1  200907000001     2020-01-09    2020-01-10               2020-01-13  ...
# 2  200907000003     2020-01-09    2020-01-10               2020-01-13  ...
# 3  200907000004     2020-01-09    2020-01-10               2020-01-13  ...
# 4  200907000006     2020-01-09    2020-01-10               2020-01-13  ...
#
#    E. coli Cloro Residual Livre(mg/L) Cloro Residual Combinado (mg/L)  \
# 0  Ausente                       1.33                             NaN
# 1  Ausente                       2.15                             NaN
# 2  Ausente                       0.94                             NaN
# 3  Ausente                       1.27                             NaN
# 4  Ausente                       2.26                             NaN
#
#   Dióxido de Cloro (mg/L) Turbidez(uT) Fluoreto(mg/L) Fluoretação  \
# 0                     NaN         0.90            0.8         Sim
# 1                     NaN         0.81            0.8         Sim
# 2                     NaN         1.10            NaN         Sim
# 3                     NaN         0.69            0.8         Sim
# 4                     NaN         0.84            0.8         Sim
#
#    Bactérias Heterotróficas(UFC/mL)  Cor Aparente (uH)    pH
# 0                               NaN                NaN  6.50
# 1                               NaN                NaN  6.50
# 2                               NaN                NaN  6.50
# 3                               NaN                NaN  6.50
# 4                               NaN                NaN  6.50
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Remove linhas da coluna cujo valor de **"Fluoreto(mg/L)"** seja **np.nan**

# %%
df_2020 = drop_na_from_column(df_2020_no_nan, 'Fluoreto(mg/L)')

# %%
df_2020.head()
# Out:
#       Município  Código IBGE  Motivo Forma              Nome         Código  \
# 0  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 1  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 3  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 4  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 6  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
#
#   N° da amostra Data da coleta Data do laudo Data de registro SISAGUA  ...  \
# 0  200907000002     2020-01-09    2020-01-10               2020-01-13  ...
# 1  200907000001     2020-01-09    2020-01-10               2020-01-13  ...
# 3  200907000004     2020-01-09    2020-01-10               2020-01-13  ...
# 4  200907000006     2020-01-09    2020-01-10               2020-01-13  ...
# 6  200907000005     2020-01-09    2020-01-10               2020-01-13  ...
#
#    E. coli Cloro Residual Livre(mg/L) Cloro Residual Combinado (mg/L)  \
# 0  Ausente                       1.33                             NaN
# 1  Ausente                       2.15                             NaN
# 3  Ausente                       1.27                             NaN
# 4  Ausente                       2.26                             NaN
# 6  Ausente                       1.06                             NaN
#
#   Dióxido de Cloro (mg/L) Turbidez(uT) Fluoreto(mg/L) Fluoretação  \
# 0                     NaN         0.90            0.8         Sim
# 1                     NaN         0.81            0.8         Sim
# 3                     NaN         0.69            0.8         Sim
# 4                     NaN         0.84            0.8         Sim
# 6                     NaN         1.02            0.8         Sim
#
#    Bactérias Heterotróficas(UFC/mL)  Cor Aparente (uH)    pH
# 0                               NaN                NaN  6.50
# 1                               NaN                NaN  6.50
# 3                               NaN                NaN  6.50
# 4                               NaN                NaN  6.50
# 6                               NaN                NaN  6.50
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Cria coluna com o valor do mês em que a coleta de Fluor foi feita

# %%
df_2020['mes_analise'] = get_month_from_row(df_2020)
# Out:
# /tmp/ipykernel_7163/512164321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['mes_analise'] = get_month_from_row(df_2020)

# %%
df_2020.head()
# Out:
#       Município  Código IBGE  Motivo Forma              Nome         Código  \
# 0  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 1  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 3  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 4  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
# 6  SALTO VELOSO       421540  Rotina   SAA  SAA SALTO VELOSO  S421540000001
#
#   N° da amostra Data da coleta Data do laudo Data de registro SISAGUA  ...  \
# 0  200907000002     2020-01-09    2020-01-10               2020-01-13  ...
# 1  200907000001     2020-01-09    2020-01-10               2020-01-13  ...
# 3  200907000004     2020-01-09    2020-01-10               2020-01-13  ...
# 4  200907000006     2020-01-09    2020-01-10               2020-01-13  ...
# 6  200907000005     2020-01-09    2020-01-10               2020-01-13  ...
#
#   Cloro Residual Livre(mg/L) Cloro Residual Combinado (mg/L)  \
# 0                       1.33                             NaN
# 1                       2.15                             NaN
# 3                       1.27                             NaN
# 4                       2.26                             NaN
# 6                       1.06                             NaN
#
#   Dióxido de Cloro (mg/L) Turbidez(uT) Fluoreto(mg/L) Fluoretação  \
# 0                     NaN         0.90            0.8         Sim
# 1                     NaN         0.81            0.8         Sim
# 3                     NaN         0.69            0.8         Sim
# 4                     NaN         0.84            0.8         Sim
# 6                     NaN         1.02            0.8         Sim
#
#   Bactérias Heterotróficas(UFC/mL)  Cor Aparente (uH)    pH mes_analise
# 0                              NaN                NaN  6.50           1
# 1                              NaN                NaN  6.50           1
# 3                              NaN                NaN  6.50           1
# 4                              NaN                NaN  6.50           1
# 6                              NaN                NaN  6.50           1
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Cria DataFrame com os nomes dos municípios

# %%
municipios = get_municipios_from_dataframe(df_2020)

# %% [markdown]
# #### Cria DataFrame com os nomes dos municípios com menos de 4 meses de análise

# %%
municipios_invalidos = get_municipios_invalidos(municipios, df_2020)

# %%
municipios_validos = get_municipios_validos(municipios, df_2020)

# %% [markdown]
# #### Remove os municípios inválidos

# %%
df_2020_municipios_validos = remove_municipios_from_dataframe(municipios_invalidos, df_2020)

# %% [markdown]
# ### Somente para validação, remover após testes

# %%
# df_2020_municipios_validos.loc[df_2020['Município'] == 'BRUSQUE', 'Fluoreto(mg/L)'] = 0.0

# %% [markdown]
# #### Conta as taxas de Fluoreto por município

# %% [markdown]
# #### Agrupa por municípios e fluoretação

# %%
df_2020_fluoreto = group_by_fluoretacao_and_municipio(df_2020_municipios_validos)
df_2020_fluoreto['IMARUI']
# Out:
# Fluoreto(mg/L)
# 0    1
# Name: count, dtype: int64

# %%
municipios_soma = get_soma_fluoretacao(df_2020_fluoreto)
municipios_soma
# Out:
# Município
# ABDON BATISTA    49
# ABELARDO LUZ     46
# AGROLANDIA       55
# AGRONOMICA       55
# AGUA DOCE        55
#                  ..
# WITMARSUM        49
# XANXERE          83
# XAVANTINA        82
# XAXIM            59
# ZORTEA           24
# Name: count, Length: 287, dtype: int64

# %% [markdown]
# #### Remove municípos que possuam mais de 50% das amostras com valor igual a zero

# %%
municipios_analises_validas = get_municipios_with_valid_samples(df_2020_fluoreto, municipios_validos, municipios_soma)
# municipios_analises_validas

# %%
df_2020_final = get_data_frame_with_valid_samples(df_2020_municipios_validos, municipios_analises_validas)
# df_2020_final = df_2020_municipios_validos[df_2020_municipios_validos['Município'].isin(municipios_analises_validas)]

# %%
df_2020_final.to_excel(output_2020)
